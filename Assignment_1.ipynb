# %% [markdown]
# <a href="https://colab.research.google.com/github/rangeet-2006/Python-Assignments/blob/main/Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1. Create a variable named carname and assign the value "Volvo" to it.
carname = "Volvo"
print("Name of the car: ",carname)
print("---------------------------------")
print("Thank you for using this program!")
# Out:
# Name of the car:  Volvo
# ---------------------------------
# Thank you for using this program!

# %%
#2. Create a variable named x and assign the value 50 to it.
x=50
print("The value of x is: ",x)
# Out:
# The value of x is:  50

# %%
#3. Create a variable called z, assign x + y to it, and display the result.
x,y = 60,40
z= x+y
print("Value of x:",x)
print("Value of y:",y)
print("------------------------")
print("The value of x+y is:",z)
# Out:
# Value of x: 60
# Value of y: 40
# ------------------------
# The value of x+y is: 100

# %%
#4. Insert the correct syntax to assign values to multiple variables in one line: x _y__ z = "CSE", "IT", "ECE"
x,y,z = "CSE","IT","ECE"
print("Displaying the department of the given variables :")
print("--------------------------------------------------")
print("Variable = x,","Dept.of x is:",x)
print("Variable = y,","Dept.of y is:",y)
print("Variable = z,","Dept.of z is:",z)
# Out:
# Displaying the department of the given variables :
# --------------------------------------------------
# Variable = x, Dept.of x is: CSE
# Variable = y, Dept.of y is: IT
# Variable = z, Dept.of z is: ECE

# %%
#5. Insert the correct syntax to assign the same value to all three variables in one code line: X__Y__Z__ “RCC”
x=y=z="RCC"
print("Displaying the value of the given variables :")
print("--------------------------------------------------")
print("Variable = x,","Value of x is:",x)
print("Variable = y,","Value of y is:",y)
print("Variable = z,","Value of z is:",z)
# Out:
# Displaying the value of the given variables :
# --------------------------------------------------
# Variable = x, Value of x is: RCC
# Variable = y, Value of y is: RCC
# Variable = z, Value of z is: RCC

# %%
#6. Insert the correct keyword to make the variable x belong to the global scope ____ x
def my_func():
    global x
    x= "I am a python coder."
my_func()
print(x)
# Out:
# I am a python coder.

# %%
#7. Print different types of variable using “type” method
x = "Hello World"
print(x)
print(type(x))

x =50
print(x)
print(type(x))

x = 60.5
print(x)
print(type(x))

x = 3j
print(x)
print(type(x))

x = ["rcciit", "for", "rcciit"]
print(x)
print(type(x))

x = ("rcciit", "for", "rcciit")
print(x)
print(type(x))

x = range(10)
print(x)
print(type(x))

x = {"name": "Suraj", "age": 24}
print(x)
print(type(x))

x = {"rcciit", "for", "rcciit"}
print(x)
print(type(x))

x = frozenset({"rcciit", "for", "rcciit","cse"})
print(x)
print(type(x))

x = True
print(x)
print(type(x))

x = b"Rcciit"
print(x)
print(type(x))
# Out:
# Hello World
# <class 'str'>
# 50
# <class 'int'>
# 60.5
# <class 'float'>
# 3j
# <class 'complex'>
# ['rcciit', 'for', 'rcciit']
# <class 'list'>
# ('rcciit', 'for', 'rcciit')
# <class 'tuple'>
# range(0, 10)
# <class 'range'>
# {'name': 'Suraj', 'age': 24}
# <class 'dict'>
# {'rcciit', 'for'}
# <class 'set'>
# frozenset({'rcciit', 'cse', 'for'})
# <class 'frozenset'>
# True
# <class 'bool'>
# b'Rcciit'
# <class 'bytes'>
